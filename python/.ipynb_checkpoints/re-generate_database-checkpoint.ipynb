# %% [markdown]
# # Génération automatique de la base de données à partir de sauvegardes CSV
# ### Margaux BRULIARD
# ### 18 mars 2021

# %% [markdown]
# L'ensemble des fichiers sont contenus dans le dossier `save_database`

# %%
import csv
import os
import sqlite3 as bdd

# %% [markdown]
# On commence par re-créer la base de données `database.db`

# %%
path_db = '../database_2.db'

# on vérifie si la base de données existe déjà
if os.path.exists(path_db):
    x = input("La BDD existe déjà. Etes vous sur de vouloir écraser les données ? [Y/n]")
    if (x == 'Y'):
        os.system('rm ../database_2.db')
    else:
        exit()
# ....

os.system("touch ../database_2.db") # creation du fichier
connexion = bdd.connect("../database_2.db") # connexion à la base de données
curseur = connexion.cursor()
# Out:
# La BDD existe déjà. Etes vous sur de vouloir écraser les données ? [Y/n]Y

# %% [markdown]
# On lit le fichier `creation.sql` pour lancer les requêtes dans la base de données

# %%
queries = None
with open('save_database/creation.sql', 'r') as fichier:
    queries = fichier.read()
# ...
curseur.executescript(queries)
connexion.commit()

# %% [markdown]
# Maintenant que les tables sont construites, nous allons pouvoir les remplir

# %%
table_names = ['categories', 'individus', 'films', 'distribution', 'notes', 'forum', 'users']
for table in table_names:
    with open('save_database/save_' + table + '.csv', newline='') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=';', quoting=csv.QUOTE_NONNUMERIC)
        row_i = 0
        for line in csv_reader:
            if row_i != 0:
                values = line
                for i in range(0, len(values)):
                    if (type(values[i])) is not str:
                        values[i] = int(values[i])

                # ...
                query = "INSERT INTO {} VALUES {}".format(table, tuple(values))
                print(query)
                curseur.execute(query)

            # ...
            row_i += 1
        # ...
        
        connexion.commit()    
    # ...
# ...
# Out:
# INSERT INTO categories VALUES (1, 'Action')
# INSERT INTO categories VALUES (2, 'Aventure')
# INSERT INTO categories VALUES (3, 'Comédie')
# INSERT INTO categories VALUES (4, 'Policier')
# INSERT INTO categories VALUES (5, 'Drame')
# INSERT INTO categories VALUES (6, 'Fantastique')
# INSERT INTO categories VALUES (7, 'Horreur')
# INSERT INTO categories VALUES (8, 'Musical')
# INSERT INTO categories VALUES (9, 'Mystère')
# INSERT INTO categories VALUES (10, 'Romance')
# INSERT INTO categories VALUES (11, 'Science Fiction')
# INSERT INTO categories VALUES (12, 'Court-Métrage')
# INSERT INTO categories VALUES (13, 'Guerre')
# INSERT INTO categories VALUES (14, 'Western')
# INSERT INTO individus VALUES (1, 'Albaicon', 'Rafael', 'Espagne', 1919, 'https://w.notrecinema.com/images/usercontent/new2018/images/stars/85000/vign/v_153936.jpg')
# INSERT INTO individus VALUES (2, 'Milius', 'John', 'US', 1944, 'http://www.gstatic.com/tv/thumb/persons/73304/73304_v9_bb.jpg')
# INSERT INTO individus VALUES (3, 'DeMille', 'Cecil B.', 'Ashfield', 1881, 'https://cdn1.cinenode.com/author_picture/8/cecil-b-demille-8133-264-432.jpg')
# INSERT INTO individus VALUES (4, 'Benatar', 'Pat', 'US', 1953, 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/0a/PAT_BENATAR_2007-09-07_%28cropped%29.jpg/260px-PAT_BENATAR_2007-09-07_%28cropped%29.jpg')
# INSERT INTO individus VALUES (5, 'Lang', 'Fritz', 'Autriche', 1890, 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/20/Fritz_Lang_%281969%29.jpg/1200px-Fritz_Lang_%281969%29.jpg')
# INSERT INTO individus VALUES (6, 'Beller', 'Kathleen', 'US', 1956, 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/63/Kathleen_Beller_on_the_set_of_Touched.jpg/220px-Kathleen_Beller_on_the_set_of_Touched.jpg')
# INSERT INTO individus VALUES (7, 'Mastorakis', 'Nico', 'Grèce', 1941, 'https://m.media-amazon.com/images/M/MV5BMTQyMDM2MDY4OV5BMl5BanBnXkFtZTcwNTgwMDQ5MQ@@._V1_UY317_CR81,0,214,317_AL_.jpg')
# INSERT INTO individus VALUES (8, 'Drury', 'David', 'UK', 1933, 'https://img.discogs.com/lH8spt_8ByPV4-Dt5G19pyDzpRI=/fit-in/300x300/filters:strip_icc():format(jpeg):mode_rgb():quality(40)/discogs-images/A-5856953-1550352979-7817.jpeg.jpg')
# INSERT INTO individus VALUES (9, 'Bening', 'Annette', 'Topeka', 1958, 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/67/AnnetteBeningSept2013TIFF.jpg/220px-AnnetteBeningSept2013TIFF.jpg')
# INSERT INTO individus VALUES (10, 'Bjork', 'Halvar', 'Borgvattnet', 1928, 'https://upload.wikimedia.org/wikipedia/en/9/9a/HalvarBj%C3%B6rkPic.jpg')
# INSERT INTO individus VALUES (11, 'Robinson', 'Edward G.', 'Roumanie', 1893, 'https://boowiki.info/images/a540_18/220px-Edward_g_robinson.jpg')
# INSERT INTO individus VALUES (12, 'Redgrave', 'Michael', 'Bristol', 1908, 'https://anniversaire-celebrite.com/upload/250x333/michael-redgrave-250.jpg')
# INSERT INTO individus VALUES (13, 'Burns', 'George', 'US', 1896, 'https://upload.wikimedia.org/wikipedia/commons/4/49/George_Burns_1961.JPG')
# INSERT INTO individus VALUES (14, 'Rosenberg', 'Stuart', 'US', 1927, 'http://www.gstatic.com/tv/thumb/persons/60660/60660_v9_ba.jpg')
# INSERT INTO individus VALUES (15, 'Bennett', 'Julie', 'US', 1932, 'https://www.animationxpress.com/wp-content/uploads/2020/04/julie-benett-251x300.jpg')
# INSERT INTO individus VALUES (16, 'Berger', 'Senta', 'Autriche', 1941, 'https://fr.web.img6.acsta.net/pictures/14/01/03/10/57/552127.jpg')
# INSERT INTO individus VALUES (17, 'Beecher', 'Janet', 'Jefferson City', 1884, 'https://upload.wikimedia.org/wikipedia/commons/thumb/7/71/Janet_Beecher_LCCN2014703048_%28cropped%29.jpg/220px-Janet_Beecher_LCCN2014703048_%28cropped%29.jpg')
# INSERT INTO individus VALUES (18, 'Hauser', 'Wings', 'US', 1947, 'https://i.pinimg.com/originals/d9/c2/00/d9c200a4f0aa40c4bbe614818f0cf641.jpg')
# INSERT INTO individus VALUES (19, 'Wayne', 'John', 'Winterset', 1907, 'https://cdn.artphotolimited.com/images/5b9fc1ecac06024957be8806/700x700/les-geants-de-l-ouest.jpg')
# INSERT INTO individus VALUES (20, 'Gould', 'Elliott', 'US', 1938, 'https://www.notrecinema.com/images/usercontent/kpitalrisk/images/stars/16000/vign/v_2056.jpg')
'https://upload.wikimedia.org/wikipedia/commons/thumb/9/94/Robert_Downey_Jr_2014_Comic_Con_%28cropped%29.jpg/220px-Robert_Downey_Jr_2014_Comic_Con_%28cropped%29.jpg')
# INSERT INTO individus VALUES (58, 'Johansson', 'Scarlett', 'US', 1984, 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/2a/Scarlett_Johansson_by_Gage_Skidmore_2_%28cropped%2C_2%29.jpg/220px-Scarlett_Johansson_by_Gage_Skidmore_2_%28cropped%2C_2%29.jpg')
# INSERT INTO individus VALUES (59, 'Besson', 'Luc', 'FR', 1959, 'https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Luc_Besson_by_Gage_Skidmore.jpg/220px-Luc_Besson_by_Gage_Skidmore.jpg')
# INSERT INTO individus VALUES (60, 'Reno', 'Jean', 'FR', 1948, 'https://upload.wikimedia.org/wikipedia/commons/thumb/e/e3/Jean_Reno_Cannes_2016.jpg/220px-Jean_Reno_Cannes_2016.jpg')
# INSERT INTO individus VALUES (61, 'Highmore', 'Freddie', 'UK', '1992', 'https://upload.wikimedia.org/wikipedia/commons/thumb/f/f0/Freddie_Highmore_2013_%28Straighten_Crop%29.jpg/220px-Freddie_Highmore_2013_%28Straighten_Crop%29.jpg')
# INSERT INTO individus VALUES (62, 'Ritchie', 'Guy', 'UK', 1968, 'https://upload.wikimedia.org/wikipedia/commons/thumb/1/14/GuyRitchiebyKathyHutchins.jpg/220px-GuyRitchiebyKathyHutchins.jpg')
# INSERT INTO individus VALUES (63, 'Law', 'Jude', 'UK', '1972', 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/4a/Jude_Law_-_Headshot.jpg/220px-Jude_Law_-_Headshot.jpg')
# INSERT INTO films VALUES (1, 'Act of Piracy', 101, 9, 1990, 'US', 54, 'https://upload.wikimedia.org/wikipedia/en/b/b1/Act_of_Piracy_FilmPoster.jpeg')
# INSERT INTO films VALUES (2, 'Split Decisions', 96, 5, 1988, 'US', 8, 'https://upload.wikimedia.org/wikipedia/en/thumb/8/85/Split_decisions_dvd_cover.jpg/220px-Split_decisions_dvd_cover.jpg')
# INSERT INTO films VALUES (3, 'Vampires Kiss"', 103, 3, 1989, 'US', 55, 'https://upload.wikimedia.org/wikipedia/en/thumb/d/d0/Vampires_kiss.jpg/220px-Vampires_kiss.jpg')
# INSERT INTO films VALUES (5, 'Presumed Innocent', 127, 9, 1990, 'US', 44, 'https://upload.wikimedia.org/wikipedia/en/thumb/7/71/Presumed_Innocent.jpg/220px-Presumed_Innocent.jpg')
# INSERT INTO films VALUES (6, 'Reap the Wild Wind', 123, 5, 1942, 'US', 3, 'https://upload.wikimedia.org/wikipedia/en/thumb/4/4b/Reap_the_Wild_Wind.jpg/220px-Reap_the_Wild_Wind.jpg')
# INSERT INTO films VALUES (7, 'Pocket Money', 100, 3, 1972, 'US', 14, 'https://upload.wikimedia.org/wikipedia/en/thumb/c/c3/Pocket_money.jpg/220px-Pocket_money.jpg')
# INSERT INTO films VALUES (10, 'Guilty by SUS"picion"', 105, 5, 1990, 'US', 45, 'https://upload.wikimedia.org/wikipedia/en/thumb/b/b7/Guilty_by_suspicion.jpg/220px-Guilty_by_suspicion.jpg')
# INSERT INTO films VALUES (11, 'Secret Beyond the Door', 99, 9, 1948, 'US', 5, 'https://upload.wikimedia.org/wikipedia/en/5/51/SecretBeyondtheDoorPoster.jpg')
# INSERT INTO films VALUES (12, 'Scarlet Street', 103, 5, 1945, 'US', 5, 'https://upload.wikimedia.org/wikipedia/en/thumb/f/f8/Scarlet_Street_p.jpg/220px-Scarlet_Street_p.jpg')
# INSERT INTO films VALUES (13, 'Daffy Ducks Quackbusters"', 76, 1, 1988, 'US', 41, 'https://upload.wikimedia.org/wikipedia/en/thumb/3/36/Daffy_ducks_quackbusters.jpg/220px-Daffy_ducks_quackbusters.jpg')
# INSERT INTO films VALUES (15, 'Gandhi', 188, 5, 1982, 'UK', 34, 'https://upload.wikimedia.org/wikipedia/en/1/10/Gandhi-poster.png')
# INSERT INTO films VALUES (16, 'Wind & the Lion, The', 120, 1, 1975, 'US', 2, 'https://upload.wikimedia.org/wikipedia/en/thumb/9/92/Wind_and_the_lion_movie_poster.jpg/220px-Wind_and_the_lion_movie_poster.jpg')
# INSERT INTO films VALUES (17, 'Carnal Knowledge', 96, 5, 1971, 'US', 25, 'https://upload.wikimedia.org/wikipedia/en/thumb/8/8f/Carnal_knowledge.jpg/220px-Carnal_knowledge.jpg')
# INSERT INTO films VALUES (18, 'Getting Straight', 126, 3, 1970, 'US', 21, 'https://upload.wikimedia.org/wikipedia/en/thumb/9/91/Getting_straight.jpg/220px-Getting_straight.jpg')
# INSERT INTO films VALUES (21, 'Autumn Sonata', 97, 5, 1978, 'DE', 50, 'https://upload.wikimedia.org/wikipedia/en/thumb/3/34/Autumnsonataposter.jpg/220px-Autumnsonataposter.jpg')
# INSERT INTO films VALUES (22, 'Gaslight', 114, 5, 1944, 'US', 51, 'https://upload.wikimedia.org/wikipedia/commons/thumb/5/5f/Gaslight_%281944_poster%29.jpg/220px-Gaslight_%281944_poster%29.jpg')
# INSERT INTO films VALUES (23, 'Avengers', 143, 1, 2012, 'US', 56, 'https://upload.wikimedia.org/wikipedia/en/8/8a/The_Avengers_%282012_film%29_poster.jpg')
# INSERT INTO films VALUES (24, "Avengers : L'Ère d'Ultron", 142, 1, 2015, 'US', 56, 'https://upload.wikimedia.org/wikipedia/en/f/ff/Avengers_Age_of_Ultron_poster.jpg')
# INSERT INTO films VALUES (25, 'Lucy', 90, 1, 2014, 'FR', 59, 'https://upload.wikimedia.org/wikipedia/en/1/14/Lucy_%282014_film%29_poster.jpg')
# INSERT INTO films VALUES (26, 'Le Grand Bleu', 168, '', 1988, 'FR', 59, 'https://upload.wikimedia.org/wikipedia/en/thumb/c/c5/Big_Blue_poster_200px.jpg/220px-Big_Blue_poster_200px.jpg')
# INSERT INTO films VALUES (27, 'Arthur et les Minimoys', 91, 2, 2006, 'FR', 59, 'https://upload.wikimedia.org/wikipedia/en/thumb/5/59/Arthur_and_the_Invisibles_poster.jpg/220px-Arthur_and_the_Invisibles_poster.jpg')
# INSERT INTO films VALUES (28, 'Sherlock Holmes', 129, 2, 2009, 'UK', 62, 'https://fr.web.img6.acsta.net/c_310_420/medias/nmedia/18/67/70/22/19227477.jpg')
# INSERT INTO films VALUES (29, 'Sherlock Holmes: A Game of Shadows', 129, 2, 2011, 'UK', 62, 'https://fr.web.img4.acsta.net/c_310_420/medias/nmedia/18/86/23/92/19849297.jpg')
# INSERT INTO distribution VALUES (1, 29)
# INSERT INTO distribution VALUES (1, 31)
# INSERT INTO distribution VALUES (2, 42)
# INSERT INTO distribution VALUES (2, 47)
# INSERT INTO distribution VALUES (3, 52)
# INSERT INTO distribution VALUES (3, 47)
# INSERT INTO distribution VALUES (5, 43)
# INSERT INTO distribution VALUES (5, 46)
# INSERT INTO distribution VALUES (6, 19)
# INSERT INTO distribution VALUES (6, 17)
# INSERT INTO distribution VALUES (7, 27)
# INSERT INTO distribution VALUES (7, 22)
# INSERT INTO distribution VALUES (10, 30)
# INSERT INTO distribution VALUES (10, 9)
# INSERT INTO distribution VALUES (11, 12)
# INSERT INTO distribution VALUES (11, 40)
# INSERT INTO distribution VALUES (12, 11)
# INSERT INTO distribution VALUES (12, 40)
# INSERT INTO distribution VALUES (13, 28)
# INSERT INTO distribution VALUES (13, 15)
# INSERT INTO distribution VALUES (15, 36)
# INSERT INTO distribution VALUES (15, 23)
# INSERT INTO distribution VALUES (16, 33)
# INSERT INTO distribution VALUES (16, 23)
# INSERT INTO distribution VALUES (17, 38)
# INSERT INTO distribution VALUES (17, 23)
# INSERT INTO distribution VALUES (18, 20)
# INSERT INTO distribution VALUES (18, 23)
# INSERT INTO distribution VALUES (21, 10)
# INSERT INTO distribution VALUES (21, 24)
# INSERT INTO distribution VALUES (22, 26)
# INSERT INTO distribution VALUES (22, 24)
# INSERT INTO distribution VALUES (23, 57)
# INSERT INTO distribution VALUES (23, 58)
# INSERT INTO distribution VALUES (24, 58)
# INSERT INTO distribution VALUES (24, 64)
# INSERT INTO distribution VALUES (25, 58)
# INSERT INTO distribution VALUES (26, 60)
# INSERT INTO distribution VALUES (27, 30)
# INSERT INTO distribution VALUES (27, 61)
# INSERT INTO distribution VALUES (28, 57)
# INSERT INTO distribution VALUES (28, 63)
# INSERT INTO distribution VALUES (29, 57)
# INSERT INTO distribution VALUES (29, 63)
# INSERT INTO notes VALUES (1, 'nbenhaffaf', 1, '')
# INSERT INTO notes VALUES (1, 'LaVraieCelineDeVegas', 2, '')
# INSERT INTO notes VALUES (1, 'NotAwrinkle', 3, '')
# INSERT INTO notes VALUES (1, 'LeRoiPopCorn12', 5, '')
# INSERT INTO notes VALUES (1, 'GrosBolDeRiz <3', 1, '')
# INSERT INTO notes VALUES (2, 'nbenhaffaf', 5, '')
# INSERT INTO notes VALUES (2, 'ProgWebForever', 1, '')
# INSERT INTO notes VALUES (2, 'toto', 2, '')
# INSERT INTO notes VALUES (2, 'MbappéForever', 2, '')
# INSERT INTO notes VALUES (2, 'PotterHead1', 2, '')
# INSERT INTO notes VALUES (2, 'jujuCo1n', 2, '')
# INSERT INTO notes VALUES (2, 'NotAwrinkle', 1, '')
# INSERT INTO notes VALUES (2, 'LeRoiPopCorn12', 5, '')
# INSERT INTO notes VALUES (2, 'GrosBolDeRiz<3', 3, '')
# INSERT INTO notes VALUES (3, 'mbruliard', 1, '')
# INSERT INTO notes VALUES (3, 'nbenhaffaf', 5, '')
# INSERT INTO notes VALUES (3, 'ProgWebForever', 5, '')
# INSERT INTO notes VALUES (3, 'coeurDartichaud', 5, '')
# INSERT INTO notes VALUES (3, 'LuckyTheLuc', 4, '')
# INSERT INTO notes VALUES (3, 'AliceAuPaysDesBretons', 5, '')
# INSERT INTO notes VALUES (3, 'PotterHead1', 2, '')
# INSERT INTO notes VALUES (3, 'GrosBolDeRiz <3', 2, '')
# INSERT INTO notes VALUES (4, 'mbruliard;2;\r\n4;toto"', 3, '')
# INSERT INTO notes VALUES (4, 'LuckyTheLuc', 3, '')
# INSERT INTO notes VALUES (4, 'AliceAuPaysDesBretons', 5, '')
# INSERT INTO notes VALUES (4, 'JeSuisPersonne', 3, '')
# INSERT INTO notes VALUES (4, 'MbappéForever', 2, '')
# INSERT INTO notes VALUES (4, 'GrosBolDeRiz <3', 3, '')
# INSERT INTO notes VALUES (5, 'mbruliard', 5, '')
# INSERT INTO notes VALUES (5, 'ProgWebForever', 3, '')
# INSERT INTO notes VALUES (5, 'toto', 5, '')
# INSERT INTO notes VALUES (5, 'PotterHead1', 2, '')
# INSERT INTO notes VALUES (5, 'NotAwrinkle', 4, '')
# INSERT INTO notes VALUES (5, 'GrosBolDeRiz <3', 4, '')
# INSERT INTO notes VALUES (6, 'nbenhaffaf', 5, '')
# INSERT INTO notes VALUES (6, 'ProgWebForever', 3, '')
# INSERT INTO notes VALUES (6, 'toto', 2, '')
# INSERT INTO notes VALUES (6, 'coeurDartichaud', 3, '')
# INSERT INTO notes VALUES (6, 'AliceAuPaysDesBretons', 2, '')
# INSERT INTO notes VALUES (6, 'PotterHead1', 2, '')
# INSERT INTO notes VALUES (6, 'NotAwrinkle', 1, '')
# INSERT INTO notes VALUES (6, 'GrosBolDeRiz<3', 2, '')
# INSERT INTO notes VALUES (7, 'toto', 3, '')
# INSERT INTO notes VALUES (7, 'LuckyTheLuc', 3, '')
# INSERT INTO notes VALUES (7, 'LaVraieCelineDeVegas', 5, '')
# INSERT INTO notes VALUES (7, 'JeSuisPersonne', 4, '')
# INSERT INTO notes VALUES (7, 'MbappéForever;3;\r\n8;ProgWebForever"', 2, '')
# INSERT INTO notes VALUES (8, 'toto', 3, '')
# INSERT INTO notes VALUES (8, 'LaVraieCelineDeVegas', 5, '')
# INSERT INTO notes VALUES (8, 'JeSuisPersonne', 4, '')
# INSERT INTO notes VALUES (8, 'MbappéForever', 5, '')
# INSERT INTO notes VALUES (8, 'PotterHead1', 3, '')
# INSERT INTO notes VALUES (8, 'jujuCo1n', 1, '')
# INSERT INTO notes VALUES (8, 'LeRoiPopCorn12', 5, '')
# INSERT INTO notes VALUES (9, 'mbruliard', 5, '')
# INSERT INTO notes VALUES (9, 'toto', 3, '')
# INSERT INTO notes VALUES (9, 'coeurDartichaud', 5, '')
# INSERT INTO notes VALUES (9, 'JeSuisPersonne', 1, '')
# INSERT INTO notes VALUES (10, 'nbenhaffaf', 2, '')
# INSERT INTO notes VALUES (10, 'LuckyTheLuc', 3, '')
# INSERT INTO notes VALUES (10, 'AliceAuPaysDesBretons', 5, '')
# INSERT INTO notes VALUES (10, 'JeSuisPersonne', 3, '')
# INSERT INTO notes VALUES (10, 'MbappéForever', 4, '')
# INSERT INTO notes VALUES (10, 'NotAwrinkle', 2, '')
# INSERT INTO notes VALUES (11, 'mbruliard', 5, '')
# INSERT INTO notes VALUES (11, 'ProgWebForever', 1, '')
# INSERT INTO notes VALUES (11, 'toto', 2, '')
# INSERT INTO notes VALUES (11, 'coeurDartichaud', 5, '')
# INSERT INTO notes VALUES (11, 'LuckyTheLuc', 3, '')
# INSERT INTO notes VALUES (11, 'LaVraieCelineDeVegas', 2, '')
# INSERT INTO notes VALUES (11, 'AliceAuPaysDesBretons', 3, '')
# INSERT INTO notes VALUES (11, 'PotterHead1', 4, '')
# INSERT INTO notes VALUES (11, 'LeRoiPopCorn12', 4, '')
# INSERT INTO notes VALUES (12, 'ProgWebForever', 2, '')
# INSERT INTO notes VALUES (12, 'coeurDartichaud', 2, '')
# INSERT INTO notes VALUES (12, 'LuckyTheLuc', 4, '')
# INSERT INTO notes VALUES (12, 'LaVraieCelineDeVegas', 2, '')
# INSERT INTO notes VALUES (12, 'MbappéForever', 3, '')
# INSERT INTO notes VALUES (12, 'jujuCo1n', 2, '')
# INSERT INTO notes VALUES (13, 'ProgWebForever', 4, '')
# INSERT INTO notes VALUES (13, 'coeurDartichaud', 4, '')
# INSERT INTO notes VALUES (13, 'AliceAuPaysDesBretons', 3, '')
# INSERT INTO notes VALUES (13, 'JeSuisPersonne', 1, '')
# INSERT INTO notes VALUES (13, 'LeRoiPopCorn12', 4, '')
# INSERT INTO notes VALUES (13, 'GrosBolDeRiz<3', 4, '')
# INSERT INTO notes VALUES (14, 'mbruliard', 1, '')
# INSERT INTO notes VALUES (14, 'nbenhaffaf', 3, '')
# INSERT INTO notes VALUES (14, 'ProgWebForever', 4, '')
# INSERT INTO notes VALUES (14, 'toto', 3, '')
# INSERT INTO notes VALUES (14, 'coeurDartichaud', 3, '')
# INSERT INTO notes VALUES (14, 'LaVraieCelineDeVegas', 5, '')
# INSERT INTO notes VALUES (14, 'JeSuisPersonne', 1, '')
# INSERT INTO notes VALUES (14, 'MbappéForever', 3, '')
# INSERT INTO notes VALUES (14, 'PotterHead1', 4, '')
# INSERT INTO notes VALUES (14, 'jujuCo1n', 4, '')
# INSERT INTO notes VALUES (15, 'nbenhaffaf', 2, '')
# INSERT INTO notes VALUES (15, 'coeurDartichaud', 5, '')
# INSERT INTO notes VALUES (15, 'LaVraieCelineDeVegas', 3, '')
# INSERT INTO notes VALUES (15, 'AliceAuPaysDesBretons', 5, '')
# INSERT INTO notes VALUES (15, 'JeSuisPersonne', 2, '')
# INSERT INTO notes VALUES (15, 'MbappéForever', 2, '')
# INSERT INTO notes VALUES (15, 'jujuCo1n', 5, '')
# INSERT INTO notes VALUES (15, 'GrosBolDeRiz<3', 5, '')
# INSERT INTO notes VALUES (16, 'toto', 3, '')
# INSERT INTO notes VALUES (16, 'coeurDartichaud', 5, '')
# INSERT INTO notes VALUES (16, 'LuckyTheLuc', 5, '')
# INSERT INTO notes VALUES (16, 'LaVraieCelineDeVegas', 1, '')
# INSERT INTO notes VALUES (16, 'MbappéForever', 5, '')
# INSERT INTO notes VALUES (16, 'jujuCo1n', 1, '')
# INSERT INTO notes VALUES (16, 'NotAwrinkle', 3, '')
# INSERT INTO notes VALUES (16, 'LeRoiPopCorn12', 2, '')
# INSERT INTO notes VALUES (16, 'GrosBolDeRiz<3', 1, '')
# INSERT INTO notes VALUES (17, 'nbenhaffaf', 2, '')
# INSERT INTO notes VALUES (17, 'ProgWebForever', 3, '')
# INSERT INTO notes VALUES (17, 'toto', 2, '')
# INSERT INTO notes VALUES (17, 'LaVraieCelineDeVegas', 4, '')
# INSERT INTO notes VALUES (17, 'AliceAuPaysDesBretons', 1, '')
# INSERT INTO notes VALUES (17, 'NotAwrinkle', 3, '')
# INSERT INTO notes VALUES (17, 'LeRoiPopCorn12', 2, '')
# INSERT INTO notes VALUES (18, 'mbruliard', 3, '')
# INSERT INTO notes VALUES (18, 'nbenhaffaf', 5, '')
# INSERT INTO notes VALUES (18, 'toto', 5, '')
# INSERT INTO notes VALUES (18, 'coeurDartichaud', 1, '')
# INSERT INTO notes VALUES (18, 'MbappéForever', 4, '')
# INSERT INTO notes VALUES (18, 'PotterHead1', 4, '')
# INSERT INTO notes VALUES (18, 'jujuCo1n', 2, '')
# INSERT INTO notes VALUES (18, 'NotAwrinkle', 4, '')
# INSERT INTO notes VALUES (19, 'mbruliard', 2, '')
# INSERT INTO notes VALUES (19, 'nbenhaffaf', 1, '')
# INSERT INTO notes VALUES (19, 'ProgWebForever', 2, '')
# INSERT INTO notes VALUES (19, 'toto', 5, '')
# INSERT INTO notes VALUES (19, 'coeurDartichaud', 2, '')
# INSERT INTO notes VALUES (19, 'LuckyTheLuc', 3, '')
# INSERT INTO notes VALUES (19, 'LaVraieCelineDeVegas', 3, '')
# INSERT INTO notes VALUES (19, 'AliceAuPaysDesBretons', 1, '')
# INSERT INTO notes VALUES (19, 'MbappéForever', 3, '')
# INSERT INTO notes VALUES (19, 'PotterHead1', 5, '')
# INSERT INTO notes VALUES (20, 'nbenhaffaf', 1, '')
# INSERT INTO notes VALUES (20, 'toto', 1, '')
# INSERT INTO notes VALUES (20, 'PotterHead1', 1, '')
# INSERT INTO notes VALUES (20, 'jujuCo1n', 2, '')
# INSERT INTO notes VALUES (20, 'NotAwrinkle', 3, '')
# INSERT INTO notes VALUES (20, 'GrosBolDeRiz<3', 1, '')
# INSERT INTO notes VALUES (21, 'mbruliard', 1, '')
# INSERT INTO notes VALUES (21, 'nbenhaffaf', 4, '')
# INSERT INTO notes VALUES (21, 'AliceAuPaysDesBretons', 5, '')
# INSERT INTO notes VALUES (21, 'JeSuisPersonne', 1, '')
# INSERT INTO notes VALUES (21, 'MbappéForever', 1, '')
# INSERT INTO notes VALUES (21, 'jujuCo1n', 5, '')
# INSERT INTO notes VALUES (21, 'GrosBolDeRiz<3', 4, '')
# INSERT INTO notes VALUES (22, 'coeurDartichaud', 4, '')
# INSERT INTO notes VALUES (22, 'LaVraieCelineDeVegas', 2, '')
# INSERT INTO notes VALUES (22, 'AliceAuPaysDesBretons', 3, '')
# INSERT INTO notes VALUES (22, 'MbappéForever', 2, '')
# INSERT INTO notes VALUES (22, 'GrosBolDeRiz<3', 1, '')
# INSERT INTO users VALUES ('mbruliard', 'mbruliard@dodo.com', '$2y$10$vTkLce23BDKt0c1VHB3Uk.puoDFJZeafu3QgoNmjfJwkM2/oS2Ax2')
# INSERT INTO users VALUES ('nbenhaffaf', 'nbenhaffaf@dodo.com', '$2y$10$vTkLce23BDKt0c1VHB3Uk.puoDFJZeafu3QgoNmjfJwkM2/oS2Ax2')
# INSERT INTO users VALUES ('ProgWebForever', 'progwebforever@dodo.com', '$2y$10$S.hJ5XDIJJWvDyE4eQdvZOxmT/cLzENTkLweIbpSSfj6whuMJM7xu')
# INSERT INTO users VALUES ('toto', 'toto@dodo.com', '$2y$10$x2haEkjRqsVqzUGeLfooquhn6zNnTT0WzBv4JlShH4UoURQifGfKW')
# INSERT INTO users VALUES ('coeurDartichaud', 'coeurdartichaud@dodo.com', '$2y$10$vTkLce23BDKt0c1VHB3Uk.puoDFJZeafu3QgoNmjfJwkM2/oS2Ax2')
# INSERT INTO users VALUES ('LuckyTheLuc', 'luckytheluc@dodo.com', '$2y$10$vTkLce23BDKt0c1VHB3Uk.puoDFJZeafu3QgoNmjfJwkM2/oS2Ax2')
# INSERT INTO users VALUES ('LaVraieCelineDeVegas', 'lavraiecelinedevegas@dodo.com', '$2y$10$vTkLce23BDKt0c1VHB3Uk.puoDFJZeafu3QgoNmjfJwkM2/oS2Ax2')
# INSERT INTO users VALUES ('AliceAuPaysDesBretons', 'aliceaupaysdesbretons@dodo.com', '$2y$10$vTkLce23BDKt0c1VHB3Uk.puoDFJZeafu3QgoNmjfJwkM2/oS2Ax2')
# INSERT INTO users VALUES ('JeSuisPersonne', 'jesuispersonne@dodo.com', '$2y$10$vTkLce23BDKt0c1VHB3Uk.puoDFJZeafu3QgoNmjfJwkM2/oS2Ax2')
# INSERT INTO users VALUES ('MbappéForever', 'mbappéforever@dodo.com', '$2y$10$vTkLce23BDKt0c1VHB3Uk.puoDFJZeafu3QgoNmjfJwkM2/oS2Ax2')
# INSERT INTO users VALUES ('PotterHead1', 'potterhead1@dodo.com', '$2y$10$vTkLce23BDKt0c1VHB3Uk.puoDFJZeafu3QgoNmjfJwkM2/oS2Ax2')
# INSERT INTO users VALUES ('jujuCo1n', 'jujuco1n@dodo.com', '$2y$10$vTkLce23BDKt0c1VHB3Uk.puoDFJZeafu3QgoNmjfJwkM2/oS2Ax2')
# INSERT INTO users VALUES ('NotAwrinkle', 'notawrinkle@dodo.com', '$2y$10$vTkLce23BDKt0c1VHB3Uk.puoDFJZeafu3QgoNmjfJwkM2/oS2Ax2')
# INSERT INTO users VALUES ('LeRoiPopCorn12', 'leroipopcorn12@dodo.com', '$2y$10$vTkLce23BDKt0c1VHB3Uk.puoDFJZeafu3QgoNmjfJwkM2/oS2Ax2')
# INSERT INTO users VALUES ('GrosBolDeRiz<3', 'grosbolderiz@dodo.com', '$2y$10$vTkLce23BDKt0c1VHB3Uk.puoDFJZeafu3QgoNmjfJwkM2/oS2Ax2')

# %% [markdown]
# Fermeture de base de données

# %%
connexion.close()

# %%
csv_reader = csv.reader(csv_file, delimiter=';')
datas = list(csv_reader)

# on extrait la 1ere ligne qui correspond aux noms des colonnes
columns = datas[0]
datas = datas[1:]

# on traite les donnees pour que chaque vide soit considéré comme un 'NULL' dans la bdd
for line in datas:
    for i in range(0, len(line)):
        if line[i] == '':
            line[i] = 'NULL'
        # ...
    # ...
# ...

# maintenant on peut faire des queries
for line in datas:
    print(line)
    query = "INSERT INTO {} {} VALUES {}".format(table, tuple(columns), tuple(line))
    curseur.execute(query)
# ...
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-6ddbfc5fc78e> in <module>
# ----> 1 csv_reader = csv.reader(csv_file, delimiter=';')
#       2 datas = list(csv_reader)
#       3
#       4 # on extrait la 1ere ligne qui correspond aux noms des colonnes
#       5 columns = datas[0]
#
# TypeError: argument 1 must be an iterator

# %%
with open("save_database/save_categories.csv", newline='') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=';', quoting=csv.QUOTE_NONNUMERIC)
    row_i = 0
    for line in csv_reader:
        if row_i != 0:
            values = line
            for i in range(0, len(values)):
                if (type(values[i])) is not str:
                    values[i] = int(values[i])
                
            # ...
            query = "INSERT INTO {} VALUES {}".format('categories', tuple(values))
            print(query)
            
        # ...
        row_i += 1
    # ...
# ...
