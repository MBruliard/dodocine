# %% [markdown]
# # Génération automatique de la base de données à partir de sauvegardes CSV
# ### Margaux BRULIARD
# ### 18 mars 2021

# %% [markdown]
# L'ensemble des fichiers sont contenus dans le dossier `save_database`

# %%
import csv
import os
import sqlite3 as bdd

# %% [markdown]
# On commence par re-créer la base de données `database.db`

# %%
path_db = '../database_2.db'

# on vérifie si la base de données existe déjà
if os.path.exists(path_db):
    x = input("La BDD existe déjà. Etes vous sur de vouloir écraser les données ? [Y/n]")
    if (x == 'Y'):
        os.system('rm ../database_2.db')
    else:
        exit()
# ....

os.system("touch ../database_2.db") # creation du fichier
connexion = bdd.connect("../database_2.db") # connexion à la base de données
curseur = connexion.cursor()
# Out:
# La BDD existe déjà. Etes vous sur de vouloir écraser les données ? [Y/n]Y

# %% [markdown]
# On lit le fichier `creation.sql` pour lancer les requêtes dans la base de données

# %%
queries = None
with open('save_database/creation.sql', 'r') as fichier:
    queries = fichier.read()
# ...
curseur.executescript(queries)
connexion.commit()

# %%
with open("save_database/save_categories.csv", newline='') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=';', quoting=csv.QUOTE_NONNUMERIC)
    row_i = 0
    for line in csv_reader:
        if row_i != 0:
            values = line
            for i in range(0, len(values)):
                if (type(values[i])) is not str:
                    values[i] = int(values[i])
                
            # ...
            query = "INSERT INTO {} VALUES {}".format('categories', tuple(values))
            print(query)
            
        # ...
        row_i += 1
    # ...
# ...
# Out:
# INSERT INTO categories VALUES (1, 'Action')
# INSERT INTO categories VALUES (2, 'Aventure')
# INSERT INTO categories VALUES (3, 'Comédie')
# INSERT INTO categories VALUES (4, 'Policier')
# INSERT INTO categories VALUES (5, 'Drame')
# INSERT INTO categories VALUES (6, 'Fantastique')
# INSERT INTO categories VALUES (7, 'Horreur')
# INSERT INTO categories VALUES (8, 'Musical')
# INSERT INTO categories VALUES (9, 'Mystère')
# INSERT INTO categories VALUES (10, 'Romance')
# INSERT INTO categories VALUES (11, 'Science Fiction')
# INSERT INTO categories VALUES (12, 'Court-Métrage')
# INSERT INTO categories VALUES (13, 'Guerre')
# INSERT INTO categories VALUES (14, 'Western')

# %% [markdown]
# Maintenant que les tables sont construites, nous allons pouvoir les remplir

# %%
table_names = ['categories', 'films', 'distribution', 'notes', 'forum', 'users']
for table in table_names:
    with open('save_database/save_' + table + '.csv', newline='') as csv_file:
        sv_reader = csv.reader(csv_file, delimiter=';', quoting=csv.QUOTE_NONNUMERIC)
        row_i = 0
        for line in csv_reader:
            if row_i != 0:
                values = line
                for i in range(0, len(values)):
                    if (type(values[i])) is not str:
                        values[i] = int(values[i])

                # ...
                query = "INSERT INTO {} VALUES {}".format(table, tuple(values))
                print(query)
                curseur.execute(query)

            # ...
            row_i += 1
        # ...
        
        connexion.commit()    
    # ...
# ...
# Out:
# categories
# ['1', 'Action']
# ['2', 'Aventure']
# ['3', 'Comédie']
# ['4', 'Policier']
# ['5', 'Drame']
# ['6', 'Fantastique']
# ['7', 'Horreur']
# ['8', 'Musical']
# ['9', 'Mystère']
# ['10', 'Romance']
# ['11', 'Science Fiction']
# ['12', 'Court-Métrage']
# ['13', 'Guerre']
# ['14', 'Western']
# films
# ['1', 'Act of Piracy', '101', '9', '1990', 'US', 'NULL', " 'https://upload.wikimedia.org/wikipedia/en/b/b1/Act_of_Piracy_FilmPoster.jpeg'"]
# ['2', 'Split Decisions', '96', '5', '1988', 'US', '8', "'https://upload.wikimedia.org/wikipedia/en/thumb/8/85/Split_decisions_dvd_cover.jpg/220px-Split_decisions_dvd_cover.jpg'"]
# ['3', "Vampire's Kiss", '103', '3', '1989', 'US', 'NULL', "'https://upload.wikimedia.org/wikipedia/en/thumb/d/d0/Vampires_kiss.jpg/220px-Vampires_kiss.jpg'"]
# ['4', 'Nightmare at Noon', '96', '1', '1988', 'US', '7', 'NULL']
# ['5', 'Presumed Innocent', '127', '9', '1990', 'US', '44', "'https://upload.wikimedia.org/wikipedia/en/thumb/7/71/Presumed_Innocent.jpg/220px-Presumed_Innocent.jpg'"]
# ['6', 'Reap the Wild Wind', '123', '5', '1942', 'US', '3', "'https://upload.wikimedia.org/wikipedia/en/thumb/4/4b/Reap_the_Wild_Wind.jpg/220px-Reap_the_Wild_Wind.jpg'"]
# ['7', 'Pocket Money', '100', '3', '1972', 'US', '14', "'https://upload.wikimedia.org/wikipedia/en/thumb/c/c3/Pocket_money.jpg/220px-Pocket_money.jpg'"]
# ['8', 'Mary White', '102', '5', '1977', 'US', '39', 'NULL']
# ['9', 'Catch a Rising Star, Tenth Anniversary', 'NULL', '3', '1982', 'NULL', 'NULL', 'NULL']
# ['10', 'Guilty by Suspicion', '105', '5', '1990', 'US', '45', "'https://upload.wikimedia.org/wikipedia/en/thumb/b/b7/Guilty_by_suspicion.jpg/220px-Guilty_by_suspicion.jpg'"]
# ['11', 'Secret Beyond the Door', '99', '9', '1948', 'US', '5', "'https://upload.wikimedia.org/wikipedia/en/5/51/SecretBeyondtheDoorPoster.jpg'"]
# ['12', 'Scarlet Street', '103', '5', '1945', 'US', '5', "'https://upload.wikimedia.org/wikipedia/en/thumb/f/f8/Scarlet_Street_p.jpg/220px-Scarlet_Street_p.jpg'"]
# ['13', "Daffy Duck's Quackbusters", '76', '1', '1988', 'US', '41', "'https://upload.wikimedia.org/wikipedia/en/thumb/3/36/Daffy_ducks_quackbusters.jpg/220px-Daffy_ducks_quackbusters.jpg'"]
# ['14', "Rowlf's Rhapsodies with the Muppets", '55', '3', '1985', 'NULL', 'NULL', 'NULL']
# ['15', 'Gandhi', '188', '5', '1982', 'UK', '34', "'https://upload.wikimedia.org/wikipedia/en/1/10/Gandhi-poster.png'"]
# ['16', 'Wind & the Lion, The', '120', '1', '1975', 'US', '2', "'https://upload.wikimedia.org/wikipedia/en/thumb/9/92/Wind_and_the_lion_movie_poster.jpg/220px-Wind_and_the_lion_movie_poster.jpg'"]
# ['17', 'Carnal Knowledge', '96', '5', '1971', 'US', '25', "'https://upload.wikimedia.org/wikipedia/en/thumb/8/8f/Carnal_knowledge.jpg/220px-Carnal_knowledge.jpg'"]
# ['18', 'Getting Straight', '126', '3', '1970', 'US', '21', "'https://upload.wikimedia.org/wikipedia/en/thumb/9/91/Getting_straight.jpg/220px-Getting_straight.jpg'"]
# ['19', 'Scarlet Letter, The', '90', '5', '1972', 'NULL', '49', 'NULL']
# ['20', 'Count of Old Town, The', '75', '3', '1935', 'SE', '37', 'NULL']
# ['21', 'Autumn Sonata', '97', '5', '1978', 'DE', '50', "'https://upload.wikimedia.org/wikipedia/en/thumb/3/34/Autumnsonataposter.jpg/220px-Autumnsonataposter.jpg'"]
# ['22', 'Gaslight', '114', '5', '1944', 'US', '51', "'https://upload.wikimedia.org/wikipedia/commons/thumb/5/5f/Gaslight_%281944_poster%29.jpg/220px-Gaslight_%281944_poster%29.jpg'"]
# distribution
# ['1', '29']
# ['1', '31']
# ['2', '42']
# ['2', '47']
# ['3', '52']
# ['3', '47']
# ['4', '18']
# ['4', '35']
# ['5', '43']
# ['5', '46']
# ['6', '19']
# ['6', '17']
# ['7', '27']
# ['7', '22']
# ['8', '32']
# ['8', '6']
# ['9', '53']
# ['9', '4']
# ['10', '30']
# ['10', '9']
# ['11', '12']
# ['11', '40']
# ['12', '11']
# ['12', '40']
# ['13', '28']
# ['13', '15']
# ['14', '13']
# ['14', '48']
# ['15', '36']
# ['15', '23']
# ['16', '33']
# ['16', '23']
# ['17', '38']
# ['17', '23']
# ['18', '20']
# ['18', '23']
# ['19', '1']
# ['19', '16']
# ['20', '37']
# ['20', '24']
# ['21', '10']
# ['21', '24']
# ['22', '26']
# ['22', '24']
# notes
# ['1', 'nbenhaffaf', '1', 'NULL']
# ['1', 'LaVraieCelineDeVegas', '2', 'NULL']
# ['1', 'NotAwrinkle', '3', 'NULL']
# ['1', 'LeRoiPopCorn12', '5', 'NULL']
# ['1', 'GrosBolDeRiz <3', '1', 'NULL']
# ['2', 'nbenhaffaf', '5', 'NULL']
# ['2', 'ProgWebForever', '1', 'NULL']
# ['2', 'toto', '2', 'NULL']
# ['2', 'MbappéForever', '2', 'NULL']
# ['2', 'PotterHead1', '2', 'NULL']
# ['2', 'jujuCo1n', '2', 'NULL']
# ['2', 'NotAwrinkle', '1', 'NULL']
# ['2', 'LeRoiPopCorn12', '5', 'NULL']
# ['2', 'GrosBolDeRiz <3', '3', 'NULL']
# ['3', 'mbruliard', '1', 'NULL']
# ['3', 'nbenhaffaf', '5', 'NULL']
# ['3', 'ProgWebForever', '5', 'NULL']
# ['3', 'coeurDartichaud', '5', 'NULL']
# ['3', 'LuckyTheLuc', '4', 'NULL']
# ['3', 'AliceAuPaysDesBretons', '5', 'NULL']
# ['3', 'PotterHead1', '2', 'NULL']
# ['3', 'GrosBolDeRiz <3', '2', 'NULL']
# ['4', 'mbruliard', '2', 'NULL']
# ['4', 'toto', '3', 'NULL']
# ['4', 'LuckyTheLuc', '3', 'NULL']
# ['4', 'AliceAuPaysDesBretons', '5', 'NULL']
# ['4', 'JeSuisPersonne', '3', 'NULL']
# ['4', 'MbappéForever', '2', 'NULL']
# ['4', 'GrosBolDeRiz <3', '3', 'NULL']
# ['5', 'mbruliard', '5', 'NULL']
# ['5', 'ProgWebForever', '3', 'NULL']
# ['5', 'toto', '5', 'NULL']
# ['5', 'PotterHead1', '2', 'NULL']
# ['5', 'NotAwrinkle', '4', 'NULL']
# ['5', 'GrosBolDeRiz <3', '4', 'NULL']
# ['6', 'nbenhaffaf', '5', 'NULL']
# ['6', 'ProgWebForever', '3', 'NULL']
# ['6', 'toto', '2', 'NULL']
# ['6', 'coeurDartichaud', '3', 'NULL']
# ['6', 'AliceAuPaysDesBretons', '2', 'NULL']
# ['6', 'PotterHead1', '2', 'NULL']
# ['6', 'NotAwrinkle', '1', 'NULL']
# ['6', 'GrosBolDeRiz <3', '2', 'NULL']
# ['7', 'toto', '3', 'NULL']
# ['7', 'LuckyTheLuc', '3', 'NULL']
# ['7', 'LaVraieCelineDeVegas', '5', 'NULL']
# ['7', 'JeSuisPersonne', '4', 'NULL']
# ['7', 'MbappéForever', '3', 'NULL']
# ['8', 'ProgWebForever', '2', 'NULL']
# ['8', 'toto', '3', 'NULL']
# ['8', 'LaVraieCelineDeVegas', '5', 'NULL']
# ['8', 'JeSuisPersonne', '4', 'NULL']
# ['8', 'MbappéForever', '5', 'NULL']
# ['8', 'PotterHead1', '3', 'NULL']
# ['8', 'jujuCo1n', '1', 'NULL']
# ['8', 'LeRoiPopCorn12', '5', 'NULL']
# ['9', 'mbruliard', '5', 'NULL']
# ['9', 'toto', '3', 'NULL']
# ['9', 'coeurDartichaud', '5', 'NULL']
# ['9', 'JeSuisPersonne', '1', 'NULL']
# ['10', 'nbenhaffaf', '2', 'NULL']
# ['10', 'LuckyTheLuc', '3', 'NULL']
# ['10', 'AliceAuPaysDesBretons', '5', 'NULL']
# ['10', 'JeSuisPersonne', '3', 'NULL']
# ['10', 'MbappéForever', '4', 'NULL']
# ['10', 'NotAwrinkle', '2', 'NULL']
# ['11', 'mbruliard', '5', 'NULL']
# ['11', 'ProgWebForever', '1', 'NULL']
# ['11', 'toto', '2', 'NULL']
# ['11', 'coeurDartichaud', '5', 'NULL']
# ['11', 'LuckyTheLuc', '3', 'NULL']
# ['11', 'LaVraieCelineDeVegas', '2', 'NULL']
# ['11', 'AliceAuPaysDesBretons', '3', 'NULL']
# ['11', 'PotterHead1', '4', 'NULL']
# ['11', 'LeRoiPopCorn12', '4', 'NULL']
# ['12', 'ProgWebForever', '2', 'NULL']
# ['12', 'coeurDartichaud', '2', 'NULL']
# ['12', 'LuckyTheLuc', '4', 'NULL']
# ['12', 'LaVraieCelineDeVegas', '2', 'NULL']
# ['12', 'MbappéForever', '3', 'NULL']
# ['12', 'jujuCo1n', '2', 'NULL']
# ['13', 'ProgWebForever', '4', 'NULL']
# ['13', 'coeurDartichaud', '4', 'NULL']
# ['13', 'AliceAuPaysDesBretons', '3', 'NULL']
# ['13', 'JeSuisPersonne', '1', 'NULL']
# ['13', 'LeRoiPopCorn12', '4', 'NULL']
# ['13', 'GrosBolDeRiz <3', '4', 'NULL']
# ['14', 'mbruliard', '1', 'NULL']
# ['14', 'nbenhaffaf', '3', 'NULL']
# ['14', 'ProgWebForever', '4', 'NULL']
# ['14', 'toto', '3', 'NULL']
# ['14', 'coeurDartichaud', '3', 'NULL']
# ['14', 'LaVraieCelineDeVegas', '5', 'NULL']
# ['14', 'JeSuisPersonne', '1', 'NULL']
# ['14', 'MbappéForever', '3', 'NULL']
# ['14', 'PotterHead1', '4', 'NULL']
# ['14', 'jujuCo1n', '4', 'NULL']
# ['15', 'nbenhaffaf', '2', 'NULL']
# ['15', 'coeurDartichaud', '5', 'NULL']
# ['15', 'LaVraieCelineDeVegas', '3', 'NULL']
# ['15', 'AliceAuPaysDesBretons', '5', 'NULL']
# ['15', 'JeSuisPersonne', '2', 'NULL']
# ['15', 'MbappéForever', '2', 'NULL']
# ['15', 'jujuCo1n', '5', 'NULL']
# ['15', 'GrosBolDeRiz <3', '5', 'NULL']
# ['16', 'toto', '3', 'NULL']
# ['16', 'coeurDartichaud', '5', 'NULL']
# ['16', 'LuckyTheLuc', '5', 'NULL']
# ['16', 'LaVraieCelineDeVegas', '1', 'NULL']
# ['16', 'MbappéForever', '5', 'NULL']
# ['16', 'jujuCo1n', '1', 'NULL']
# ['16', 'NotAwrinkle', '3', 'NULL']
# ['16', 'LeRoiPopCorn12', '2', 'NULL']
# ['16', 'GrosBolDeRiz <3', '1', 'NULL']
# ['17', 'nbenhaffaf', '2', 'NULL']
# ['17', 'ProgWebForever', '3', 'NULL']
# ['17', 'toto', '2', 'NULL']
# ['17', 'LaVraieCelineDeVegas', '4', 'NULL']
# ['17', 'AliceAuPaysDesBretons', '1', 'NULL']
# ['17', 'NotAwrinkle', '3', 'NULL']
# ['17', 'LeRoiPopCorn12', '2', 'NULL']
# ['18', 'mbruliard', '3', 'NULL']
# ['18', 'nbenhaffaf', '5', 'NULL']
# ['18', 'toto', '5', 'NULL']
# ['18', 'coeurDartichaud', '1', 'NULL']
# ['18', 'MbappéForever', '4', 'NULL']
# ['18', 'PotterHead1', '4', 'NULL']
# ['18', 'jujuCo1n', '2', 'NULL']
# ['18', 'NotAwrinkle', '4', 'NULL']
# ['19', 'mbruliard', '2', 'NULL']
# ['19', 'nbenhaffaf', '1', 'NULL']
# ['19', 'ProgWebForever', '2', 'NULL']
# ['19', 'toto', '5', 'NULL']
# ['19', 'coeurDartichaud', '2', 'NULL']
# ['19', 'LuckyTheLuc', '3', 'NULL']
# ['19', 'LaVraieCelineDeVegas', '3', 'NULL']
# ['19', 'AliceAuPaysDesBretons', '1', 'NULL']
# ['19', 'MbappéForever', '3', 'NULL']
# ['19', 'PotterHead1', '5', 'NULL']
# ['20', 'nbenhaffaf', '1', 'NULL']
# ['20', 'toto', '1', 'NULL']
# ['20', 'PotterHead1', '1', 'NULL']
# ['20', 'jujuCo1n', '2', 'NULL']
# ['20', 'NotAwrinkle', '3', 'NULL']
# ['20', 'GrosBolDeRiz <3', '1', 'NULL']
# ['21', 'mbruliard', '1', 'NULL']
# ['21', 'nbenhaffaf', '4', 'NULL']
# ['21', 'AliceAuPaysDesBretons', '5', 'NULL']
# ['21', 'JeSuisPersonne', '1', 'NULL']
# ['21', 'MbappéForever', '1', 'NULL']
# ['21', 'jujuCo1n', '5', 'NULL']
# ['21', 'GrosBolDeRiz <3', '4', 'NULL']
# ['22', 'coeurDartichaud', '4', 'NULL']
# ['22', 'LaVraieCelineDeVegas', '2', 'NULL']
# ['22', 'AliceAuPaysDesBretons', '3', 'NULL']
# ['22', 'MbappéForever', '2', 'NULL']
# ['22', 'GrosBolDeRiz <3', '1', 'NULL']
# forum
# users
# ['mbruliard', 'mbruliard@dodo.com', '$2y$10$vTkLce23BDKt0c1VHB3Uk.puoDFJZeafu3QgoNmjfJwkM2/oS2Ax2']
# ['nbenhaffaf', 'nbenhaffaf@dodo.com', '$2y$10$vTkLce23BDKt0c1VHB3Uk.puoDFJZeafu3QgoNmjfJwkM2/oS2Ax2']
# ['ProgWebForever', 'progwebforever@dodo.com', '$2y$10$S.hJ5XDIJJWvDyE4eQdvZOxmT/cLzENTkLweIbpSSfj6whuMJM7xu']
# ['toto', 'toto@dodo.com', '$2y$10$x2haEkjRqsVqzUGeLfooquhn6zNnTT0WzBv4JlShH4UoURQifGfKW']
# ['coeurDartichaud', 'coeurdartichaud@dodo.com', '$2y$10$vTkLce23BDKt0c1VHB3Uk.puoDFJZeafu3QgoNmjfJwkM2/oS2Ax2']
# ['LuckyTheLuc', 'luckytheluc@dodo.com', '$2y$10$vTkLce23BDKt0c1VHB3Uk.puoDFJZeafu3QgoNmjfJwkM2/oS2Ax2']
# ['LaVraieCelineDeVegas', 'lavraiecelinedevegas@dodo.com', '$2y$10$vTkLce23BDKt0c1VHB3Uk.puoDFJZeafu3QgoNmjfJwkM2/oS2Ax2']
# ['AliceAuPaysDesBretons', 'aliceaupaysdesbretons@dodo.com', '$2y$10$vTkLce23BDKt0c1VHB3Uk.puoDFJZeafu3QgoNmjfJwkM2/oS2Ax2']
# ['JeSuisPersonne', 'jesuispersonne@dodo.com', '$2y$10$vTkLce23BDKt0c1VHB3Uk.puoDFJZeafu3QgoNmjfJwkM2/oS2Ax2']
# ['MbappéForever', 'mbappéforever@dodo.com', '$2y$10$vTkLce23BDKt0c1VHB3Uk.puoDFJZeafu3QgoNmjfJwkM2/oS2Ax2']
# ['PotterHead1', 'potterhead1@dodo.com', '$2y$10$vTkLce23BDKt0c1VHB3Uk.puoDFJZeafu3QgoNmjfJwkM2/oS2Ax2']
# ['jujuCo1n', 'jujuco1n@dodo.com', '$2y$10$vTkLce23BDKt0c1VHB3Uk.puoDFJZeafu3QgoNmjfJwkM2/oS2Ax2']
# ['NotAwrinkle', 'notawrinkle@dodo.com', '$2y$10$vTkLce23BDKt0c1VHB3Uk.puoDFJZeafu3QgoNmjfJwkM2/oS2Ax2']
# ['LeRoiPopCorn12', 'leroipopcorn12@dodo.com', '$2y$10$vTkLce23BDKt0c1VHB3Uk.puoDFJZeafu3QgoNmjfJwkM2/oS2Ax2']
# ['GrosBolDeRiz <3', 'grosbolderiz <3@dodo.com', '$2y$10$vTkLce23BDKt0c1VHB3Uk.puoDFJZeafu3QgoNmjfJwkM2/oS2Ax2']

# %% [markdown]
# Fermeture de base de données

# %%
connexion.close()

# %%
csv_reader = csv.reader(csv_file, delimiter=';')
        datas = list(csv_reader)
        
        # on extrait la 1ere ligne qui correspond aux noms des colonnes
        columns = datas[0]
        datas = datas[1:]
        
        # on traite les donnees pour que chaque vide soit considéré comme un 'NULL' dans la bdd
        for line in datas:
            for i in range(0, len(line)):
                if line[i] == '':
                    line[i] = 'NULL'
                # ...
            # ...
        # ...
        
        # maintenant on peut faire des queries
        for line in datas:
            print(line)
            query = "INSERT INTO {} {} VALUES {}".format(table, tuple(columns), tuple(line))
            curseur.execute(query)
        # ...
